# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
#pd.set_option('max_columns', 100)

# %%
# LOADING DATASET 

df= pd.read_csv('creditcard_2023.csv')
df.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
# Checking for Shape of dataset including Rows and Columns
df.shape
# Out:
# (568630, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
#type of columns
df.dtypes
# Out:
# id          int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
# Data preparation
#dropping a column 
#df.drop([''],axis=1)

# %%
# CHECKING FOR ANY MISSING VALUES IN THE DATASET
df.isna().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# ANOTHER WAY OF CHECKING MISSING VALUES
df.isnull().values.any()
# Out:
# False

# %%
#information about numeric and statistic data in the dataset
df.describe()
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17
# std    164149.486121  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   7.997245e-18 -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17
# ...

# %%
# As X and y are dependant and independent features extracted from our normal datasets
X = df.drop('Class', axis =1)
y = df['Class']
X.shape, y.shape
# Out:
# ((568630, 30), (568630,))

# %%
#check for duplicates
import pandas as pd
df= pd.read_csv('creditcard_2023.csv')
print(f"Duplicates: {df.duplicated().sum()}")
# Out:
# Duplicates: 0

# %%
# drop duplicates
df = df.drop_duplicates()
print(f"Duplicates: {df.duplicated().sum()}")
# Out:
# Duplicates: 0

# %%
#Checking null values
df.isnull().any()
# Out:
# id        False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
#Rename our columns
df.rename(columns= {'id': 'User_id'})
# Out:
#         User_id        V1        V2        V3        V4        V5        V6  \
# 0             0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898
# 1             1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605
# 2             2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481
# 3             3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312
# 4             4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549
# ...         ...       ...       ...       ...       ...       ...       ...
# 568625   568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626   568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627   568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628   568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629   568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
# ...

# %%
#removing redundant features
import seaborn as sns
import matplotlib.pyplot as plt

#correlation heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=False, cmap= 'coolwarm')
plt.title("correlation Heatmap")
plt.show()

#feature selection using correlation threshold
correlation_threshold = 0.8
correlation_matrix = df.corr()
for col in correlation_matrix.columns:
    if any(correlation_matrix[col][correlation_matrix[col]<1] > correlation_threshold):
        df.drop(col, axis=1, inplace = True)

# %%
import pandas as pd

# Verify if df exists before using it
if 'df' not in locals() and 'df' not in globals():
    raise NameError("The variable 'df' is not defined. Please load your dataset before using it.")

print(df.isna())  # Check for missing values
# Out:
#            V1     V2     V3     V4     V5     V6     V7     V8     V9    V10  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 568625  False  False  False  False  False  False  False  False  False  False
# 568626  False  False  False  False  False  False  False  False  False  False
# 568627  False  False  False  False  False  False  False  False  False  False
# 568628  False  False  False  False  False  False  False  False  False  False
# 568629  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
df.isna().sum()
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# dtype: int64

# %%
df['V1'].value_counts()
# Out:
# V1
# -1.704517    3539
# -2.459141    1399
# -1.161336     259
# -1.065576     255
# -1.522526     246
#              ...
# -0.272852       1
#  1.822123       1
#  0.556931       1
#  0.276802       1
# -0.795144       1
# Name: count, Length: 552035, dtype: int64

# %%
df['V1'].value_counts().head(10).plot(kind = 'bar', title= 'number of counts of column V1')
# Out:
# <Axes: title={'center': 'number of counts of column V1'}, xlabel='V1'>

# %%
sns.pairplot(df, vars=['V1', 'V2', 'V3', 'V4'])
plt.show()

# %%
# Dropping any riws wuth missing values 
df_corr= df[['V1','V2']].dropna().corr()
df_corr
# Out:
#           V1        V2
# V1  1.000000 -0.561184
# V2 -0.561184  1.000000

# %%
sns.heatmap(df_corr, annot = True)
# Out:
# <Axes: >
